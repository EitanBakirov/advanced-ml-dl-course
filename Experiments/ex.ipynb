# %% [markdown]
# <a href="https://colab.research.google.com/github/ariel-hedvat/AdvancedMLDLCourseAssignments/blob/main/Experiments/ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rs_datasets
# Out:
# Collecting rs_datasets
#   Downloading rs_datasets-0.5.1-py3-none-any.whl (21 kB)
# Collecting datatable (from rs_datasets)
#   Downloading datatable-1.1.0-cp310-cp310-manylinux_2_35_x86_64.whl (82.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rs_datasets) (1.5.3)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from rs_datasets) (4.7.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from rs_datasets) (14.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rs_datasets) (4.66.2)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from rs_datasets) (2.0.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from rs_datasets) (1.5.16)
# Collecting py7zr (from rs_datasets)
#   Downloading py7zr-0.21.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from rs_datasets) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown->rs_datasets) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown->rs_datasets) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown->rs_datasets) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->rs_datasets) (4.12.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle->rs_datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->rs_datasets) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->rs_datasets) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->rs_datasets) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->rs_datasets) (6.1.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->rs_datasets) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rs_datasets) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->rs_datasets) (1.25.2)
# Collecting texttable (from py7zr->rs_datasets)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr->rs_datasets)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 70.5 MB/s eta 0:00:00
# Collecting pyzstd>=0.15.9 (from py7zr->rs_datasets)
#   Downloading pyzstd-0.15.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 37.6 MB/s eta 0:00:00
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr->rs_datasets)
#   Downloading pyppmd-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 16.0 MB/s eta 0:00:00
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr->rs_datasets)
#   Downloading pybcj-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 5.9 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr->rs_datasets)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr->rs_datasets)
#   Downloading inflate64-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 10.7 MB/s eta 0:00:00
# Collecting brotli>=1.1.0 (from py7zr->rs_datasets)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 79.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from py7zr->rs_datasets) (5.9.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->rs_datasets) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->rs_datasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->rs_datasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->rs_datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->rs_datasets) (3.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->rs_datasets) (1.7.1)
# Installing collected packages: texttable, brotli, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, datatable, py7zr, rs_datasets
# Successfully installed brotli-1.1.0 datatable-1.1.0 inflate64-1.0.0 multivolumefile-0.2.3 py7zr-0.21.0 pybcj-1.0.2 pycryptodomex-3.20.0 pyppmd-1.1.0 pyzstd-0.15.9 rs_datasets-0.5.1 texttable-1.7.0

# %%
from rs_datasets import MillionSongDataset
msd = MillionSongDataset()
msd.info()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# INFO:rs_datasets:Getting Million Song Dataset...
# INFO:rs_datasets:Downloading Echo Nest Taste Subprofile train data...
# 512MB [00:06, 75.0MB/s]
# INFO:rs_datasets:Downloading evaluation data for MSD Challenge...
# 37.1MB [00:00, 43.6MB/s]
# INFO:rs_datasets:Downloading list of matching errors...
# 2.04MB [00:00, 7.94MB/s]

# %%
from rs_datasets import Lastfm
lastfm = Lastfm()
lastfm.info()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# INFO:rs_datasets:Downloading Last.fm 360k dataset...
#   4%|▍         | 21.5M/569M [00:17<07:17, 1.25MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-32d7b9862536> in <cell line: 2>()
#       1 from rs_datasets import Lastfm
# ----> 2 lastfm = Lastfm()
#       3 lastfm.info()
#
# /usr/local/lib/python3.10/dist-packages/rs_datasets/lastfm.py in __init__(self, path)
#      13         folder = join(self.data_folder, 'lastfm')
#      14         if not exists(folder):
# ---> 15             self._download(folder)
#      16
#      17         self.play_counts = dt.fread(
#
# /usr/local/lib/python3.10/dist-packages/rs_datasets/generic_dataset.py in decorated(self, path, *args, **kwargs)
#      40     def decorated(self, path, *args, **kwargs):
#      41         try:
# ---> 42             func(self, path, *args, **kwargs)
#      43         except Exception as e:
#      44             if os.path.exists(path):
#
# /usr/local/lib/python3.10/dist-packages/rs_datasets/lastfm.py in _download(self, path)
#      29         self.logger.info('Downloading Last.fm 360k dataset...')
#      30         url = 'http://mtg.upf.edu/static/datasets/last.fm/lastfm-dataset-360K.tar.gz'
# ---> 31         download_dataset(url, join(self.data_folder, 'lastfm.tar.gz'))
#      32         rename(join(self.data_folder, 'lastfm-dataset-360K'), path)
#
# /usr/local/lib/python3.10/dist-packages/rs_datasets/data_loader/loaders.py in download_dataset(url, destination_path, manage_folder)
#      19     :return: None
#      20     """
# ---> 21     download_url(url, destination_path)
#      22     extract(destination_path, manage_folder)
#      23     rm_if_exists(destination_path)
#
# /usr/local/lib/python3.10/dist-packages/rs_datasets/data_loader/loaders.py in download_url(url, filename)
#      36             progress.total = total
#      37             progress.update(chunksize)
# ---> 38         return urlretrieve(url, filename, reporthook=report)
#
# /usr/lib/python3.10/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     268
#     269             while True:
# --> 270                 block = fp.read(bs)
#     271                 if not block:
#     272                     break
#
# /usr/lib/python3.10/http/client.py in read(self, amt)
#     464                 # clip the read to the "end of response"
#     465                 amt = self.length
# --> 466             s = self.fp.read(amt)
#     467             if not s and amt:
#     468                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.3-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.8/251.8 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.0.7)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2024.2.2)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.3 spotipy-2.23.0

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = '77dfb9bcdceb47a3913a2ef7cb9556d3'

client_secret = '112f981ab2774a3896bef84788c083ad'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
for track in sp.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_uri = track["track"]["uri"]

    #Track name
    track_name = track["track"]["name"]

    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)

    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]

    #Album
    album = track["track"]["album"]["name"]

    #Popularity of the track
    track_pop = track["track"]["popularity"]

# %%
sp.audio_features(track_uri)[0]
# Out:
# {'danceability': 0.726,
#  'energy': 0.698,
#  'key': 5,
#  'loudness': -4.165,
#  'mode': 1,
#  'speechiness': 0.0431,
#  'acousticness': 0.049,
#  'instrumentalness': 0,
#  'liveness': 0.309,
#  'valence': 0.867,
#  'tempo': 143.994,
#  'type': 'audio_features',
#  'id': '3w3y8KPTfNeOKPiqUTakBh',
#  'uri': 'spotify:track:3w3y8KPTfNeOKPiqUTakBh',
#  'track_href': 'https://api.spotify.com/v1/tracks/3w3y8KPTfNeOKPiqUTakBh',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3w3y8KPTfNeOKPiqUTakBh',
#  'duration_ms': 233478,
#  'time_signature': 4}

# %%
# Function to search for a track
def search_track(track_name):
    results = sp.search(q=track_name, type='track', limit=1)
    if results['tracks']['items']:
        return results['tracks']['items'][0]
    else:
        return None

# %%
# Replace 'TRACK_NAME' with the name of the track you want to search for
track_name = '(The Angels Wanna Wear My) Red Shoes'
track_info = search_track(track_name)

# Print track info if found
if track_info:
    print("Track Name:", track_info['name'])
    print("Artist(s):", ", ".join([artist['name'] for artist in track_info['artists']]))
    print("Album:", track_info['album']['name'])
    print("Release Date:", track_info['album']['release_date'])
    print("Preview URL:", track_info['preview_url'])
    print("External URL:", track_info['external_urls']['spotify'])
else:
    print("Track not found.")
# Out:
# Track Name: (The Angels Wanna Wear My) Red Shoes
# Artist(s): Elvis Costello
# Album: My Aim Is True
# Release Date: 1977-07-22
# Preview URL: None
# External URL: https://open.spotify.com/track/0GmLrYUBXDC5vti77zBZfJ

# %%
# Function to get playlist URI by name
def get_playlist_uri_by_name(playlist_name):
    playlists = sp.search(q=playlist_name, type='playlist')
    if playlists['playlists']['items']:
        return playlists['playlists']['items'][0]['uri']
    else:
        print("Playlist not found")
        return None

# %%
get_playlist_uri_by_name("HARD ROCK 2010")
# Out:
# 'spotify:playlist:4BVbcWaTw03yqXQJxlijXv'

# %%
# Function to get songs in a playlist by playlist ID
def get_songs_in_playlist(playlist_id):
    # Retrieve tracks from the playlist
    playlist_tracks = sp.playlist_tracks(playlist_id)

    # Extract information for each track
    for idx, track in enumerate(playlist_tracks['items'], 1):
        track_name = track['track']['name']
        artists = ', '.join([artist['name'] for artist in track['track']['artists']])
        album_name = track['track']['album']['name']
        print(f"{idx}. {track_name} - {artists} - {album_name}")

# %%
# Call the function to get songs in the playlist
get_songs_in_playlist("4BVbcWaTw03yqXQJxlijXv")
# Out:
# 1. Kryptonite - 3 Doors Down - The Better Life
# 2. Someday - Nickelback - The Long Road
# 3. I Will Not Bow - Breaking Benjamin - Dear Agony
# 4. Pain - Three Days Grace - One-X
# 5. Fake It - Seether - Finding Beauty In Negative Spaces (Bonus Track Version)
# 6. Last Resort - Papa Roach - Infest
# 7. Bring Me To Life - Evanescence - Fallen
# 8. Headstrong - Trapt - Trapt
# 9. I Hate Everything About You - Three Days Grace - Three Days Grace
# 10. Numb - Linkin Park - Meteora
# 11. Remedy - Seether - Karma and Effect
# 12. The Diary of Jane - Single Version - Breaking Benjamin - Phobia (Clean Version)
# 13. Savior - Rise Against - Appeal To Reason
# 14. Control - Puddle Of Mudd - Come Clean
# 15. So Cold - Remix - Breaking Benjamin - We Are Not Alone
# 16. Youth of the Nation - P.O.D. - Satellite (U.S. Version)
# 17. Cold - Crossfade - Crossfade
# 18. Bad Girlfriend - Theory of a Deadman - Scars & Souvenirs (Special Edition)
# 19. One Step Closer - Linkin Park - Hybrid Theory (Bonus Edition)
# 20. Comatose - Skillet - Comatose
# 21. Forever - Papa Roach - The Paramour Sessions
# 22. Scars - Papa Roach - Getting Away With Murder
# 23. Prayer Of The Refugee - Rise Against - The Sufferer & The Witness
# 24. The Kill - Thirty Seconds To Mars - A Beautiful Lie
# 25. The Red - Chevelle - Wonder What's Next (Expanded Edition)
# 26. Sound of Madness - Shinedown - The Sound of Madness
# 27. It's Been Awhile - Staind - Break the Cycle
# 28. Wasteland - 10 Years - The Autumn Effect
# 29. Fine Again - Seether - Disclaimer
# 30. How You Remind Me - Nickelback - Silver Side Up
# 31. She Hates Me - Puddle Of Mudd - Come Clean
# 32. Crazy Bitch - Buckcherry - 15
# 33. Smooth Criminal - Alien Ant Farm - Anthology
# 34. In the End - Linkin Park - Hybrid Theory (Bonus Edition)
# 35. Breakdown - Seether - Finding Beauty In Negative Spaces (Bonus Track Version)
# 36. Blurry - Puddle Of Mudd - Come Clean
# 37. Loser - 3 Doors Down - The Better Life
# 38. It's Not Over - Daughtry - Daughtry (Deluxe Edition)
# 39. Through Glass - Stone Sour - Come What(ever) May [10th Anniversary Edition]
# 40. Broken - Seether, Amy Lee - Disclaimer II
# 41. So Far Away - Staind - 14 Shades of Grey
# 42. Careless Whisper - Seether - Finding Beauty In Negative Spaces (Bonus Track Version)
# 43. Lips Of An Angel - Hinder - Extreme Behavior
# 44. Right Here - Staind - Chapter V
# 45. Meant to Live - Switchfoot - The Beautiful Letdown (Deluxe Version)
# 46. Broken - Seether - Disclaimer
# 47. Not Meant to Be - Theory of a Deadman - Scars & Souvenirs (Special Edition)
# 48. Rise Above This - Seether - Finding Beauty In Negative Spaces (Bonus Track Version)
# 49. Better Than Me - Hinder - Extreme Behavior
# 50. Bother - Stone Sour - Stone Sour
# 51. Sorry - Buckcherry - 15
# 52. Just Like You - Three Days Grace - Three Days Grace
# 53. Paralyzer - Finger Eleven - Them Vs. You Vs. Me (Deluxe Edition)
# 54. Break - Three Days Grace - Life Starts Now
# 55. Whispers in the Dark - Skillet - Comatose
# 56. Awake and Alive - Skillet - Awake
# 57. Hero - Skillet - Awake
# 58. 45 - Shinedown - Leave a Whisper (Deluxe Edition)
# 59. End Of Me - Apocalyptica, Gavin Rossdale - 7th Symphony
# 60. Here Without You - 3 Doors Down - Away From The Sun
# 61. Savin' Me - Nickelback - All the Right Reasons
# 62. Over You - Daughtry - Daughtry (Deluxe Edition)
# 63. Addicted - Saving Abel - Saving Abel
# 64. The Good Life - Three Days Grace - Life Starts Now
# 65. I Stand Alone - Godsmack - Faceless
# 66. Truth - Seether - Karma and Effect
# 67. Second Chance - Shinedown - The Sound of Madness
# 68. Overcome - Creed - Full Circle
# 69. Life is Beautiful - Sixx:A.M. - The Heroin Diaries Soundtrack
# 70. Gasoline - Seether - Disclaimer
# 71. Call Me When You're Sober - Evanescence - The Open Door
# 72. My Sacrifice - Creed - Weathered
# 73. Simple Man - Acoustic - Shinedown - Leave a Whisper (Deluxe Edition)
# 74. When I'm Gone - 3 Doors Down - Away From The Sun
# 75. It's Not My Time - 3 Doors Down - 3 Doors Down
# 76. Psycho - Puddle Of Mudd - Famous
# 77. Crawling - Linkin Park - Hybrid Theory (Bonus Edition)
# 78. Re-Education (Through Labor) - Rise Against - Appeal To Reason
# 79. Figured You Out - Nickelback - The Long Road
# 80. Feelin' Way Too Damn Good - Nickelback - The Long Road
# 81. Too Bad - Nickelback - Silver Side Up
# 82. Animals - Nickelback - All the Right Reasons
# 83. Burn It to the Ground - Nickelback - Dark Horse
# 84. Something in Your Mouth - Nickelback - Dark Horse
# 85. Breath - Breaking Benjamin - Phobia (Clean Version)
# 86. Crawling In The Dark - Hoobastank - Hoobastank (20th Anniversary Edition)
# 87. Slither - Velvet Revolver - Contraband
# 88. Fall to Pieces - Velvet Revolver - Contraband
# 89. Blow Me Away - Soundtrack Version - Breaking Benjamin - Blow Me Away
# 90. Inside the Fire - Disturbed - Indestructible (Deluxe Edition)
# 91. Indestructible - Disturbed - Indestructible (Deluxe Edition)
# 92. World so Cold - Three Days Grace - Life Starts Now
# 93. Stricken - Disturbed - Ten Thousand Fists
# 94. Almost Easy - Avenged Sevenfold - Avenged Sevenfold
# 95. Afterlife - Avenged Sevenfold - Avenged Sevenfold
# 96. Beast and the Harlot - Avenged Sevenfold - City of Evil
# 97. Animal I Have Become - Three Days Grace - One-X
# 98. Never Too Late - Three Days Grace - One-X
# 99. Riot - Three Days Grace - One-X
# 100. Country Song - Seether - Holding Onto Strings Better Left To Fray

# %%
# Function to get track info for all tracks in a playlist
def get_track_info_by_playlist(playlist_uri):
    playlist_tracks = sp.playlist_tracks(playlist_uri)["items"]
    track_info_list = []

    for track in playlist_tracks:
        track_info = track["track"]
        track_uri = track_info["uri"]
        artist_uri = track_info["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)
        artist_name = track_info["artists"][0]["name"]
        artist_popularity = artist_info["popularity"]
        artist_genres = artist_info["genres"]
        album_name = track_info["album"]["name"]
        track_name = track_info["name"]
        track_popularity = track_info["popularity"]

        # Append information for the current track
        track_info_list.append({
            "Track URI": track_uri,
            "Track Name": track_name,
            "Main Artist": artist_name,
            "Artist Popularity": artist_popularity,
            "Artist Genres": artist_genres,
            "Album": album_name,
            "Track Popularity": track_popularity
        })

    return track_info_list

# %%
get_track_info_by_playlist("4BVbcWaTw03yqXQJxlijXv")
# Out:
# [{'Track URI': 'spotify:track:6ZOBP3NvffbU4SZcrnt1k6',
#   'Track Name': 'Kryptonite',
#   'Main Artist': '3 Doors Down',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge', 'rock'],
#   'Album': 'The Better Life',
#   'Track Popularity': 83},
#  {'Track URI': 'spotify:track:4PkJ7c9y1CwpuVOiJODnCZ',
#   'Track Name': 'Someday',
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'The Long Road',
#   'Track Popularity': 74},
#  {'Track URI': 'spotify:track:2yXyz4NLTZx9CLdXfLTp5E',
#   'Track Name': 'I Will Not Bow',
#   'Main Artist': 'Breaking Benjamin',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Dear Agony',
#   'Track Popularity': 73},
#  {'Track URI': 'spotify:track:5PZ2cqh9Yem2g6cTSOLllz',
#   'Track Name': 'Pain',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'One-X',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:4eAwB5pnKFTmsgc3zWoYO0',
#   'Track Name': 'Fake It',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Finding Beauty In Negative Spaces (Bonus Track Version)',
#   'Track Popularity': 76},
#  {'Track URI': 'spotify:track:5W8YXBz9MTIDyrpYaCg2Ky',
#   'Track Name': 'Last Resort',
#   'Main Artist': 'Papa Roach',
#   'Artist Popularity': 71,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'rap metal',
#    'rap rock',
#    'rock'],
#   'Album': 'Infest',
#   'Track Popularity': 83},
#  {'Track URI': 'spotify:track:0COqiPhxzoWICwFCS4eZcp',
#   'Track Name': 'Bring Me To Life',
#   'Main Artist': 'Evanescence',
#   'Artist Popularity': 72,
#   'Artist Genres': ['alternative metal'],
#   'Album': 'Fallen',
#   'Track Popularity': 86},
#  {'Track URI': 'spotify:track:1AEYT6VxrxXPMoQUxsY0E4',
#   'Track Name': 'Headstrong',
#   'Main Artist': 'Trapt',
#   'Artist Popularity': 57,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Trapt',
#   'Track Popularity': 75},
#  {'Track URI': 'spotify:track:0M955bMOoilikPXwKLYpoi',
#   'Track Name': 'I Hate Everything About You',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'Three Days Grace',
#   'Track Popularity': 78},
#  {'Track URI': 'spotify:track:2nLtzopw4rPReszdYBJU6h',
#   'Track Name': 'Numb',
#   'Main Artist': 'Linkin Park',
#   'Artist Popularity': 85,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'rap metal',
#    'rock'],
#   'Album': 'Meteora',
#   'Track Popularity': 88},
#  {'Track URI': 'spotify:track:5ynxx6zC4dgzsMHLYQ04Dc',
#   'Track Name': 'Remedy',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Karma and Effect',
#   'Track Popularity': 72},
#  {'Track URI': 'spotify:track:0faXHILILebCGnJBPU6KJJ',
#   'Track Name': 'The Diary of Jane - Single Version',
#   'Main Artist': 'Breaking Benjamin',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Phobia (Clean Version)',
#   'Track Popularity': 76},
#  {'Track URI': 'spotify:track:1vcxF91pWs9uNwDROuiCPB',
#   'Track Name': 'Savior',
#   'Main Artist': 'Rise Against',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal',
#    'chicago hardcore',
#    'chicago punk',
#    'hardcore punk',
#    'modern rock',
#    'post-grunge',
#    'punk'],
#   'Album': 'Appeal To Reason',
#   'Track Popularity': 80},
#  {'Track URI': 'spotify:track:575Sz3R4xOhueUstPObylF',
#   'Track Name': 'Control',
#   'Main Artist': 'Puddle Of Mudd',
#   'Artist Popularity': 63,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Come Clean',
#   'Track Popularity': 66},
#  {'Track URI': 'spotify:track:4BJyt25nburVwbnESDeIc7',
#   'Track Name': 'So Cold - Remix',
#   'Main Artist': 'Breaking Benjamin',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'We Are Not Alone',
#   'Track Popularity': 65},
#  {'Track URI': 'spotify:track:0UrWr7Jnu1heq1o99ZwUd0',
#   'Track Name': 'Youth of the Nation',
#   'Main Artist': 'P.O.D.',
#   'Artist Popularity': 61,
#   'Artist Genres': ['alternative metal',
#    'funk metal',
#    'nu metal',
#    'rap metal',
#    'rap rock'],
#   'Album': 'Satellite (U.S. Version)',
#   'Track Popularity': 71},
#  {'Track URI': 'spotify:track:6ZxrUCaynLgKSUudACOTwj',
#   'Track Name': 'Cold',
#   'Main Artist': 'Crossfade',
#   'Artist Popularity': 57,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Crossfade',
#   'Track Popularity': 72},
#  {'Track URI': 'spotify:track:5m7on0zpnmeAXy72ANrmfU',
#   'Track Name': 'Bad Girlfriend',
#   'Main Artist': 'Theory of a Deadman',
#   'Artist Popularity': 62,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge'],
#   'Album': 'Scars & Souvenirs (Special Edition)',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:3K4HG9evC7dg3N0R9cYqk4',
#   'Track Name': 'One Step Closer',
#   'Main Artist': 'Linkin Park',
#   'Artist Popularity': 85,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'rap metal',
#    'rock'],
#   'Album': 'Hybrid Theory (Bonus Edition)',
#   'Track Popularity': 83},
#  {'Track URI': 'spotify:track:5pRElcsPZrgZXkoON2o5Go',
#   'Track Name': 'Comatose',
#   'Main Artist': 'Skillet',
#   'Artist Popularity': 73,
#   'Artist Genres': ['alternative metal',
#    'christian alternative rock',
#    'christian music',
#    'christian rock'],
#   'Album': 'Comatose',
#   'Track Popularity': 70},
#  {'Track URI': 'spotify:track:7zQ5nqAKKfk0gtBgV70gyq',
#   'Track Name': 'Forever',
#   'Main Artist': 'Papa Roach',
#   'Artist Popularity': 71,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'rap metal',
#    'rap rock',
#    'rock'],
#   'Album': 'The Paramour Sessions',
#   'Track Popularity': 58},
#  {'Track URI': 'spotify:track:3TAtUJc4Sj913Cs5gBUeu0',
#   'Track Name': 'Scars',
#   'Main Artist': 'Papa Roach',
#   'Artist Popularity': 71,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'rap metal',
#    'rap rock',
#    'rock'],
#   'Album': 'Getting Away With Murder',
#   'Track Popularity': 65},
#  {'Track URI': 'spotify:track:4OSbctVD37ycS0H3rwRm72',
#   'Track Name': 'Prayer Of The Refugee',
#   'Main Artist': 'Rise Against',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal',
#    'chicago hardcore',
#    'chicago punk',
#    'hardcore punk',
#    'modern rock',
#    'post-grunge',
#    'punk'],
#   'Album': 'The Sufferer & The Witness',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:0lP4HYLmvowOKdsQ7CVkuq',
#   'Track Name': 'The Kill',
#   'Main Artist': 'Thirty Seconds To Mars',
#   'Artist Popularity': 69,
#   'Artist Genres': ['modern rock', 'post-grunge'],
#   'Album': 'A Beautiful Lie',
#   'Track Popularity': 80},
#  {'Track URI': 'spotify:track:1gyee1JuFFiP476LQpRMYU',
#   'Track Name': 'The Red',
#   'Main Artist': 'Chevelle',
#   'Artist Popularity': 63,
#   'Artist Genres': ['alternative metal',
#    'christian rock',
#    'nu metal',
#    'post-grunge'],
#   'Album': "Wonder What's Next (Expanded Edition)",
#   'Track Popularity': 73},
#  {'Track URI': 'spotify:track:0W9Xvd4Qx1aZPxEi94vgRY',
#   'Track Name': 'Sound of Madness',
#   'Main Artist': 'Shinedown',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'The Sound of Madness',
#   'Track Popularity': 72},
#  {'Track URI': 'spotify:track:25CMmGsl22APKhfuj4Tp7j',
#   'Track Name': "It's Been Awhile",
#   'Main Artist': 'Staind',
#   'Artist Popularity': 64,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Break the Cycle',
#   'Track Popularity': 71},
#  {'Track URI': 'spotify:track:3pO37BXsjMC2wApALxGbuB',
#   'Track Name': 'Wasteland',
#   'Main Artist': '10 Years',
#   'Artist Popularity': 57,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'The Autumn Effect',
#   'Track Popularity': 67},
#  {'Track URI': 'spotify:track:4eTIe5eqds88bA9ua6p5p6',
#   'Track Name': 'Fine Again',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Disclaimer',
#   'Track Popularity': 70},
#  {'Track URI': 'spotify:track:0gmbgwZ8iqyMPmXefof8Yf',
#   'Track Name': 'How You Remind Me',
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'Silver Side Up',
#   'Track Popularity': 85},
#  {'Track URI': 'spotify:track:16DhvbuyvJob4Q9GHNYu2n',
#   'Track Name': 'She Hates Me',
#   'Main Artist': 'Puddle Of Mudd',
#   'Artist Popularity': 63,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Come Clean',
#   'Track Popularity': 75},
#  {'Track URI': 'spotify:track:5XfQTbialQHn9PhDb0p85H',
#   'Track Name': 'Crazy Bitch',
#   'Main Artist': 'Buckcherry',
#   'Artist Popularity': 56,
#   'Artist Genres': ['alternative metal',
#    'glam metal',
#    'hard rock',
#    'nu metal',
#    'post-grunge',
#    'sleaze rock'],
#   'Album': '15',
#   'Track Popularity': 7},
#  {'Track URI': 'spotify:track:5z6xHjCZr7a7AIcy8sPBKy',
#   'Track Name': 'Smooth Criminal',
#   'Main Artist': 'Alien Ant Farm',
#   'Artist Popularity': 59,
#   'Artist Genres': ['alternative metal',
#    'funk metal',
#    'nu metal',
#    'post-grunge'],
#   'Album': 'Anthology',
#   'Track Popularity': 77},
#  {'Track URI': 'spotify:track:60a0Rd6pjrkxjPbaKzXjfq',
#   'Track Name': 'In the End',
#   'Main Artist': 'Linkin Park',
#   'Artist Popularity': 85,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'rap metal',
#    'rock'],
#   'Album': 'Hybrid Theory (Bonus Edition)',
#   'Track Popularity': 89},
#  {'Track URI': 'spotify:track:0Q9f1NBvKCC37V4oJVEgCh',
#   'Track Name': 'Breakdown',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Finding Beauty In Negative Spaces (Bonus Track Version)',
#   'Track Popularity': 59},
#  {'Track URI': 'spotify:track:6lSr3iZTC144PKhvbPFzMp',
#   'Track Name': 'Blurry',
#   'Main Artist': 'Puddle Of Mudd',
#   'Artist Popularity': 63,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Come Clean',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:1aC1IBAETh2XYGOE8kCC6t',
#   'Track Name': 'Loser',
#   'Main Artist': '3 Doors Down',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge', 'rock'],
#   'Album': 'The Better Life',
#   'Track Popularity': 63},
#  {'Track URI': 'spotify:track:234RqTZmnDTnxWlVciXHLD',
#   'Track Name': "It's Not Over",
#   'Main Artist': 'Daughtry',
#   'Artist Popularity': 64,
#   'Artist Genres': ['alternative metal',
#    'neo mellow',
#    'pop rock',
#    'post-grunge'],
#   'Album': 'Daughtry (Deluxe Edition)',
#   'Track Popularity': 67},
#  {'Track URI': 'spotify:track:5NeIONQWJ25uPylJBJiO4c',
#   'Track Name': 'Through Glass',
#   'Main Artist': 'Stone Sour',
#   'Artist Popularity': 63,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Come What(ever) May [10th Anniversary Edition]',
#   'Track Popularity': 72},
#  {'Track URI': 'spotify:track:507bYMYfbm6sUS9iEAaeSd',
#   'Track Name': 'Broken',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Disclaimer II',
#   'Track Popularity': 72},
#  {'Track URI': 'spotify:track:6FOpPA0a80RuBqqgDozvja',
#   'Track Name': 'So Far Away',
#   'Main Artist': 'Staind',
#   'Artist Popularity': 64,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': '14 Shades of Grey',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:46eHxWRKmtYhUHPDRgclt6',
#   'Track Name': 'Careless Whisper',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Finding Beauty In Negative Spaces (Bonus Track Version)',
#   'Track Popularity': 67},
#  {'Track URI': 'spotify:track:40LQiUUUKXVGyNs09lHVjW',
#   'Track Name': 'Lips Of An Angel',
#   'Main Artist': 'Hinder',
#   'Artist Popularity': 60,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Extreme Behavior',
#   'Track Popularity': 74},
#  {'Track URI': 'spotify:track:6S7mmHgyWOG6pIYuL4YrfQ',
#   'Track Name': 'Right Here',
#   'Main Artist': 'Staind',
#   'Artist Popularity': 64,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Chapter V',
#   'Track Popularity': 61},
#  {'Track URI': 'spotify:track:2md2i5QvelRFnafpnd6LOg',
#   'Track Name': 'Meant to Live',
#   'Main Artist': 'Switchfoot',
#   'Artist Popularity': 58,
#   'Artist Genres': ['ccm', 'christian alternative rock', 'christian music'],
#   'Album': 'The Beautiful Letdown (Deluxe Version)',
#   'Track Popularity': 65},
#  {'Track URI': 'spotify:track:5nakPOknHu3XkeeHoVvhCd',
#   'Track Name': 'Broken',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Disclaimer',
#   'Track Popularity': 54},
#  {'Track URI': 'spotify:track:5xyACR2lzIyzFepF4qlAas',
#   'Track Name': 'Not Meant to Be',
#   'Main Artist': 'Theory of a Deadman',
#   'Artist Popularity': 62,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge'],
#   'Album': 'Scars & Souvenirs (Special Edition)',
#   'Track Popularity': 57},
#  {'Track URI': 'spotify:track:4dZ4iHhsqQAQ4em4abLB6C',
#   'Track Name': 'Rise Above This',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Finding Beauty In Negative Spaces (Bonus Track Version)',
#   'Track Popularity': 59},
#  {'Track URI': 'spotify:track:10fddGyyeUquZZ2uPTjD7P',
#   'Track Name': 'Better Than Me',
#   'Main Artist': 'Hinder',
#   'Artist Popularity': 60,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Extreme Behavior',
#   'Track Popularity': 64},
#  {'Track URI': 'spotify:track:0AfIsqZ4gTUg9CwwW2jLeK',
#   'Track Name': 'Bother',
#   'Main Artist': 'Stone Sour',
#   'Artist Popularity': 63,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Stone Sour',
#   'Track Popularity': 65},
#  {'Track URI': 'spotify:track:0EbnUc05YEKhZRKgbrZWpq',
#   'Track Name': 'Sorry',
#   'Main Artist': 'Buckcherry',
#   'Artist Popularity': 56,
#   'Artist Genres': ['alternative metal',
#    'glam metal',
#    'hard rock',
#    'nu metal',
#    'post-grunge',
#    'sleaze rock'],
#   'Album': '15',
#   'Track Popularity': 3},
#  {'Track URI': 'spotify:track:0CA3RxBx2xSQXPfpmUBK1v',
#   'Track Name': 'Just Like You',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'Three Days Grace',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:28IEbk5a7twNTbUEvWslUb',
#   'Track Name': 'Paralyzer',
#   'Main Artist': 'Finger Eleven',
#   'Artist Popularity': 61,
#   'Artist Genres': ['alternative metal',
#    'canadian rock',
#    'funk metal',
#    'nu metal',
#    'post-grunge'],
#   'Album': 'Them Vs. You Vs. Me (Deluxe Edition)',
#   'Track Popularity': 78},
#  {'Track URI': 'spotify:track:4urxRqBRiaH0i20OKBsgxc',
#   'Track Name': 'Break',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'Life Starts Now',
#   'Track Popularity': 70},
#  {'Track URI': 'spotify:track:6rSuL1ViLO7Aljn2WD09s4',
#   'Track Name': 'Whispers in the Dark',
#   'Main Artist': 'Skillet',
#   'Artist Popularity': 73,
#   'Artist Genres': ['alternative metal',
#    'christian alternative rock',
#    'christian music',
#    'christian rock'],
#   'Album': 'Comatose',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:0nkzd3yNniB767zSDDdLZ3',
#   'Track Name': 'Awake and Alive',
#   'Main Artist': 'Skillet',
#   'Artist Popularity': 73,
#   'Artist Genres': ['alternative metal',
#    'christian alternative rock',
#    'christian music',
#    'christian rock'],
#   'Album': 'Awake',
#   'Track Popularity': 73},
#  {'Track URI': 'spotify:track:4CbKVDZkYKdv69I4bCaKUq',
#   'Track Name': 'Hero',
#   'Main Artist': 'Skillet',
#   'Artist Popularity': 73,
#   'Artist Genres': ['alternative metal',
#    'christian alternative rock',
#    'christian music',
#    'christian rock'],
#   'Album': 'Awake',
#   'Track Popularity': 75},
#  {'Track URI': 'spotify:track:420JGkyLfLUZcgBHKiIK9v',
#   'Track Name': '45',
#   'Main Artist': 'Shinedown',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Leave a Whisper (Deluxe Edition)',
#   'Track Popularity': 69},
#  {'Track URI': 'spotify:track:2KznDKv0HpLoy7RsseJVWf',
#   'Track Name': 'End Of Me',
#   'Main Artist': 'Apocalyptica',
#   'Artist Popularity': 59,
#   'Artist Genres': ['cello', 'finnish metal'],
#   'Album': '7th Symphony',
#   'Track Popularity': 0},
#  {'Track URI': 'spotify:track:3NLrRZoMF0Lx6zTlYqeIo4',
#   'Track Name': 'Here Without You',
#   'Main Artist': '3 Doors Down',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge', 'rock'],
#   'Album': 'Away From The Sun',
#   'Track Popularity': 78},
#  {'Track URI': 'spotify:track:4Gd9PUEuOTOJtbgd4YxLXM',
#   'Track Name': "Savin' Me",
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'All the Right Reasons',
#   'Track Popularity': 69},
#  {'Track URI': 'spotify:track:2R5uY1gbIKzGB1yAOH067s',
#   'Track Name': 'Over You',
#   'Main Artist': 'Daughtry',
#   'Artist Popularity': 64,
#   'Artist Genres': ['alternative metal',
#    'neo mellow',
#    'pop rock',
#    'post-grunge'],
#   'Album': 'Daughtry (Deluxe Edition)',
#   'Track Popularity': 64},
#  {'Track URI': 'spotify:track:3pxCXv0NACYfYnLjFcQW5D',
#   'Track Name': 'Addicted',
#   'Main Artist': 'Saving Abel',
#   'Artist Popularity': 55,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Saving Abel',
#   'Track Popularity': 72},
#  {'Track URI': 'spotify:track:55KYlnsC6nYnr3IykbmJwE',
#   'Track Name': 'The Good Life',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'Life Starts Now',
#   'Track Popularity': 66},
#  {'Track URI': 'spotify:track:44NRdYQw7P0GWuiunRv3hr',
#   'Track Name': 'I Stand Alone',
#   'Main Artist': 'Godsmack',
#   'Artist Popularity': 67,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'rap metal'],
#   'Album': 'Faceless',
#   'Track Popularity': 73},
#  {'Track URI': 'spotify:track:5KUUpftdyMnSZNOyO3qydy',
#   'Track Name': 'Truth',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Karma and Effect',
#   'Track Popularity': 57},
#  {'Track URI': 'spotify:track:0CwYG1UnRmOx8Q1EzElCIL',
#   'Track Name': 'Second Chance',
#   'Main Artist': 'Shinedown',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'The Sound of Madness',
#   'Track Popularity': 71},
#  {'Track URI': 'spotify:track:25TQBBKOrtTfnH6QBM9He1',
#   'Track Name': 'Overcome',
#   'Main Artist': 'Creed',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Full Circle',
#   'Track Popularity': 60},
#  {'Track URI': 'spotify:track:3AoSuIey90cH9PI8HUoHOQ',
#   'Track Name': 'Life is Beautiful',
#   'Main Artist': 'Sixx:A.M.',
#   'Artist Popularity': 53,
#   'Artist Genres': ['alternative metal', 'post-grunge'],
#   'Album': 'The Heroin Diaries Soundtrack',
#   'Track Popularity': 3},
#  {'Track URI': 'spotify:track:5ih5herXfvp5coBVFhmoAW',
#   'Track Name': 'Gasoline',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Disclaimer',
#   'Track Popularity': 63},
#  {'Track URI': 'spotify:track:663Karu2rvKLdnY0eo1n3M',
#   'Track Name': "Call Me When You're Sober",
#   'Main Artist': 'Evanescence',
#   'Artist Popularity': 72,
#   'Artist Genres': ['alternative metal'],
#   'Album': 'The Open Door',
#   'Track Popularity': 71},
#  {'Track URI': 'spotify:track:2VSbEXqs6NbNiZSTcHlIDR',
#   'Track Name': 'My Sacrifice',
#   'Main Artist': 'Creed',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Weathered',
#   'Track Popularity': 74},
#  {'Track URI': 'spotify:track:4VuKGQiCzE5BdSdvp6Hjoh',
#   'Track Name': 'Simple Man - Acoustic',
#   'Main Artist': 'Shinedown',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Leave a Whisper (Deluxe Edition)',
#   'Track Popularity': 61},
#  {'Track URI': 'spotify:track:3WbphvawbMZ8FyqDxYGdSQ',
#   'Track Name': "When I'm Gone",
#   'Main Artist': '3 Doors Down',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge', 'rock'],
#   'Album': 'Away From The Sun',
#   'Track Popularity': 75},
#  {'Track URI': 'spotify:track:0uybt73QFXaLCoxuVf6fhm',
#   'Track Name': "It's Not My Time",
#   'Main Artist': '3 Doors Down',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge', 'rock'],
#   'Album': '3 Doors Down',
#   'Track Popularity': 65},
#  {'Track URI': 'spotify:track:3e2KBwxibC1rq4bA5TNKW2',
#   'Track Name': 'Psycho',
#   'Main Artist': 'Puddle Of Mudd',
#   'Artist Popularity': 63,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Famous',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:57BrRMwf9LrcmuOsyGilwr',
#   'Track Name': 'Crawling',
#   'Main Artist': 'Linkin Park',
#   'Artist Popularity': 85,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'rap metal',
#    'rock'],
#   'Album': 'Hybrid Theory (Bonus Edition)',
#   'Track Popularity': 80},
#  {'Track URI': 'spotify:track:6c1Bdvp208X0jbLmFnWbkC',
#   'Track Name': 'Re-Education (Through Labor)',
#   'Main Artist': 'Rise Against',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal',
#    'chicago hardcore',
#    'chicago punk',
#    'hardcore punk',
#    'modern rock',
#    'post-grunge',
#    'punk'],
#   'Album': 'Appeal To Reason',
#   'Track Popularity': 67},
#  {'Track URI': 'spotify:track:1Yuim9eHBfG8YUJII28XDF',
#   'Track Name': 'Figured You Out',
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'The Long Road',
#   'Track Popularity': 65},
#  {'Track URI': 'spotify:track:4i2WUspbfNZCnhkypoFKrM',
#   'Track Name': "Feelin' Way Too Damn Good",
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'The Long Road',
#   'Track Popularity': 54},
#  {'Track URI': 'spotify:track:2cCWbBmadLbKvr9xddC79R',
#   'Track Name': 'Too Bad',
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'Silver Side Up',
#   'Track Popularity': 64},
#  {'Track URI': 'spotify:track:5vvoFE63Z7yw2TTj4icSDn',
#   'Track Name': 'Animals',
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'All the Right Reasons',
#   'Track Popularity': 61},
#  {'Track URI': 'spotify:track:1jq28NGw6wdtFKx8MBPy6C',
#   'Track Name': 'Burn It to the Ground',
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'Dark Horse',
#   'Track Popularity': 78},
#  {'Track URI': 'spotify:track:6wO0vMRAJB0r1lEWBJZNOq',
#   'Track Name': 'Something in Your Mouth',
#   'Main Artist': 'Nickelback',
#   'Artist Popularity': 77,
#   'Artist Genres': ['alternative metal', 'canadian rock', 'post-grunge'],
#   'Album': 'Dark Horse',
#   'Track Popularity': 69},
#  {'Track URI': 'spotify:track:4JXfNOePhdgMOI7KZ1L25U',
#   'Track Name': 'Breath',
#   'Main Artist': 'Breaking Benjamin',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Phobia (Clean Version)',
#   'Track Popularity': 71},
#  {'Track URI': 'spotify:track:1PJRDeZSoZk7gtisdTYfLi',
#   'Track Name': 'Crawling In The Dark',
#   'Main Artist': 'Hoobastank',
#   'Artist Popularity': 65,
#   'Artist Genres': ['alternative metal',
#    'funk metal',
#    'nu metal',
#    'pop rock',
#    'post-grunge'],
#   'Album': 'Hoobastank (20th Anniversary Edition)',
#   'Track Popularity': 70},
#  {'Track URI': 'spotify:track:7kF1iPJTj3VFJX9XokQ80F',
#   'Track Name': 'Slither',
#   'Main Artist': 'Velvet Revolver',
#   'Artist Popularity': 52,
#   'Artist Genres': ['alternative metal',
#    'alternative rock',
#    'glam metal',
#    'grunge',
#    'hard rock',
#    'nu metal',
#    'post-grunge',
#    'rock',
#    'supergroup'],
#   'Album': 'Contraband',
#   'Track Popularity': 63},
#  {'Track URI': 'spotify:track:2amzrvbxYiq8AxGntIiw5V',
#   'Track Name': 'Fall to Pieces',
#   'Main Artist': 'Velvet Revolver',
#   'Artist Popularity': 52,
#   'Artist Genres': ['alternative metal',
#    'alternative rock',
#    'glam metal',
#    'grunge',
#    'hard rock',
#    'nu metal',
#    'post-grunge',
#    'rock',
#    'supergroup'],
#   'Album': 'Contraband',
#   'Track Popularity': 61},
#  {'Track URI': 'spotify:track:5JBH2osD5Y5AneMKPOfY1s',
#   'Track Name': 'Blow Me Away - Soundtrack Version',
#   'Main Artist': 'Breaking Benjamin',
#   'Artist Popularity': 70,
#   'Artist Genres': ['alternative metal', 'nu metal', 'post-grunge'],
#   'Album': 'Blow Me Away',
#   'Track Popularity': 59},
#  {'Track URI': 'spotify:track:5cxp9kjCFyJwzv3lzeX7ku',
#   'Track Name': 'Inside the Fire',
#   'Main Artist': 'Disturbed',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal', 'nu metal', 'rap metal', 'rock'],
#   'Album': 'Indestructible (Deluxe Edition)',
#   'Track Popularity': 68},
#  {'Track URI': 'spotify:track:42ZVk59gT4tMlrZmd8Ijxf',
#   'Track Name': 'Indestructible',
#   'Main Artist': 'Disturbed',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal', 'nu metal', 'rap metal', 'rock'],
#   'Album': 'Indestructible (Deluxe Edition)',
#   'Track Popularity': 71},
#  {'Track URI': 'spotify:track:0LPx8WfsRrXCF92YtINFtN',
#   'Track Name': 'World so Cold',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'Life Starts Now',
#   'Track Popularity': 61},
#  {'Track URI': 'spotify:track:6RJdYpFQwLyNfDc5FbjkgV',
#   'Track Name': 'Stricken',
#   'Main Artist': 'Disturbed',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal', 'nu metal', 'rap metal', 'rock'],
#   'Album': 'Ten Thousand Fists',
#   'Track Popularity': 74},
#  {'Track URI': 'spotify:track:0DkmhHO4yyqCJFjosmmWPU',
#   'Track Name': 'Almost Easy',
#   'Main Artist': 'Avenged Sevenfold',
#   'Artist Popularity': 75,
#   'Artist Genres': ['alternative metal'],
#   'Album': 'Avenged Sevenfold',
#   'Track Popularity': 69},
#  {'Track URI': 'spotify:track:7zAt4tdL44D3VuzsvM0N8n',
#   'Track Name': 'Afterlife',
#   'Main Artist': 'Avenged Sevenfold',
#   'Artist Popularity': 75,
#   'Artist Genres': ['alternative metal'],
#   'Album': 'Avenged Sevenfold',
#   'Track Popularity': 74},
#  {'Track URI': 'spotify:track:6FVYwnVrnAEIRnY3bHJb46',
#   'Track Name': 'Beast and the Harlot',
#   'Main Artist': 'Avenged Sevenfold',
#   'Artist Popularity': 75,
#   'Artist Genres': ['alternative metal'],
#   'Album': 'City of Evil',
#   'Track Popularity': 65},
#  {'Track URI': 'spotify:track:56sk7jBpZV0CD31G9hEU3b',
#   'Track Name': 'Animal I Have Become',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'One-X',
#   'Track Popularity': 77},
#  {'Track URI': 'spotify:track:3HE50TVRquwXe9yv2HFoNL',
#   'Track Name': 'Never Too Late',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'One-X',
#   'Track Popularity': 71},
#  {'Track URI': 'spotify:track:1Q2fYlSdwuutWj3QplhY9q',
#   'Track Name': 'Riot',
#   'Main Artist': 'Three Days Grace',
#   'Artist Popularity': 74,
#   'Artist Genres': ['alternative metal',
#    'canadian metal',
#    'canadian rock',
#    'nu metal',
#    'post-grunge',
#    'rock'],
#   'Album': 'One-X',
#   'Track Popularity': 71},
#  {'Track URI': 'spotify:track:2abHKI9Oox4NBEhOh3HMbq',
#   'Track Name': 'Country Song',
#   'Main Artist': 'Seether',
#   'Artist Popularity': 68,
#   'Artist Genres': ['alternative metal',
#    'nu metal',
#    'post-grunge',
#    'south african rock'],
#   'Album': 'Holding Onto Strings Better Left To Fray',
#   'Track Popularity': 65}]
