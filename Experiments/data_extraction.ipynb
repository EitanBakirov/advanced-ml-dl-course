# %% [markdown]
# <a href="https://colab.research.google.com/github/ariel-hedvat/AdvancedMLDLCourseAssignments/blob/main/Experiments/data_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#installation for spotipy-API
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.3-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.8/251.8 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.0.7)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2024.2.2)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.3 spotipy-2.23.0

# %%
#imports
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import os
import zipfile
import pandas as pd
import requests
import io
import subprocess
import time

# %%
# Function to read Spotify credentials from a URL
def read_spotify_credentials_from_url(url):
    credentials = {}
    response = requests.get(url)
    if response.status_code == 200:
        lines = response.text.split('\n')
        for line in lines:
            if '=' in line:
                key, value = line.strip().split('=')
                credentials[key] = value
    else:
        print("Failed to fetch Spotify credentials. Status code:", response.status_code)
    return credentials

# %%
# Function to unzip the dataset
def unzip_dataset(zip_file_url):
    response = requests.get(zip_file_url)
    with zipfile.ZipFile(io.BytesIO(response.content), 'r') as zip_ref:
        extracted_files = {}
        for file in zip_ref.namelist():
          if file.endswith('.csv'):
                extracted_files[file] = pd.read_csv(io.BytesIO(zip_ref.read(file)), encoding='utf-8')
    return extracted_files

# %%
# Unzip the dataset
#zip_file_url = 'https://raw.githubusercontent.com/ariel-hedvat/AdvancedMLDLCourseAssignments/main/Experiments/Data/full_spotify_dataset_recreated.zip'
zip_file_url = 'https://raw.githubusercontent.com/ariel-hedvat/AdvancedMLDLCourseAssignments/main/Experiments/Data/50.zip'
data_files = unzip_dataset(zip_file_url)

# %%
data_files
# Out:
# {'50.csv':                              user_id                        artistname  \
#  0   9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
#  1   9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
#  2   9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
#  3   9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
#  4   9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
#  5   9cc0cfd4d7d7885102480dd99e7a90d6                            Lissie
#  6   9cc0cfd4d7d7885102480dd99e7a90d6                    Paul McCartney
#  7   9cc0cfd4d7d7885102480dd99e7a90d6                          Joe Echo
#  8   9cc0cfd4d7d7885102480dd99e7a90d6                    Paul McCartney
#  9   9cc0cfd4d7d7885102480dd99e7a90d6                            Lissie
#  10  9cc0cfd4d7d7885102480dd99e7a90d6                      The Breakers
#  11  9cc0cfd4d7d7885102480dd99e7a90d6                    Paul McCartney
#  12  9cc0cfd4d7d7885102480dd99e7a90d6                       The Coronas
#  13  9cc0cfd4d7d7885102480dd99e7a90d6                     Crowded House
#  14  9cc0cfd4d7d7885102480dd99e7a90d6                            Lissie
#  15  9cc0cfd4d7d7885102480dd99e7a90d6                     Crowded House
#  16  9cc0cfd4d7d7885102480dd99e7a90d6                     Crowded House
#  17  9cc0cfd4d7d7885102480dd99e7a90d6                      Joshua Radin
#  18  9cc0cfd4d7d7885102480dd99e7a90d6                      The Breakers
#  19  9cc0cfd4d7d7885102480dd99e7a90d6                 Cocktail Slippers
#  20  9cc0cfd4d7d7885102480dd99e7a90d6             Crosby, Stills & Nash
#  21  9cc0cfd4d7d7885102480dd99e7a90d6                            Lissie
#  22  9cc0cfd4d7d7885102480dd99e7a90d6                 Cocktail Slippers
#  23  9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
#  24  9cc0cfd4d7d7885102480dd99e7a90d6                   The Len Price 3
#  25  9cc0cfd4d7d7885102480dd99e7a90d6                      Joshua Radin
#  26  9cc0cfd4d7d7885102480dd99e7a90d6                   The Len Price 3
#  27  9cc0cfd4d7d7885102480dd99e7a90d6                            Lissie
#  28  9cc0cfd4d7d7885102480dd99e7a90d6                 Cocktail Slippers
#  29  9cc0cfd4d7d7885102480dd99e7a90d6                          Joe Echo
#  30  9cc0cfd4d7d7885102480dd99e7a90d6                   The Len Price 3
#  31  9cc0cfd4d7d7885102480dd99e7a90d6                          Joe Echo
#  32  9cc0cfd4d7d7885102480dd99e7a90d6                            Lissie
#  33  9cc0cfd4d7d7885102480dd99e7a90d6                    Paul McCartney
#  34  9cc0cfd4d7d7885102480dd99e7a90d6                   The Len Price 3
#  35  9cc0cfd4d7d7885102480dd99e7a90d6                 Cocktail Slippers
#  36  9cc0cfd4d7d7885102480dd99e7a90d6                     Crowded House
#  37  9cc0cfd4d7d7885102480dd99e7a90d6                     Crowded House
#  38  9cc0cfd4d7d7885102480dd99e7a90d6                            Lissie
#  39  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
#  40  9cc0cfd4d7d7885102480dd99e7a90d6                          Joe Echo
#  41  9cc0cfd4d7d7885102480dd99e7a90d6                          Joe Echo
#  42  9cc0cfd4d7d7885102480dd99e7a90d6                      Joshua Radin
#  43  9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
#  44  9cc0cfd4d7d7885102480dd99e7a90d6                          Joe Echo
#  45  9cc0cfd4d7d7885102480dd99e7a90d6                          Joe Echo
#  46  9cc0cfd4d7d7885102480dd99e7a90d6                   The Len Price 3
#  47  9cc0cfd4d7d7885102480dd99e7a90d6                   The Len Price 3
#  48  9cc0cfd4d7d7885102480dd99e7a90d6                       The Coronas
#
#                                              trackname    playlistname
#  0                (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
#  1   (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
#  2                                    7 Years Too Late  HARD ROCK 2010
#  3                               Accidents Will Happen  HARD ROCK 2010
#  4                                              Alison  HARD ROCK 2010
#  5                                         All Be Okay  HARD ROCK 2010
#  6                                     Band On The Run  HARD ROCK 2010
#  7                                           Beautiful  HARD ROCK 2010
#  8   Blackbird - Live at CitiField, NYC - Digital A...  HARD ROCK 2010
#  9                                         Bright Side  HARD ROCK 2010
#  10                                    Dance The Go-Go  HARD ROCK 2010
#  11                                      Dance Tonight  HARD ROCK 2010
#  12                                      Decision Time  HARD ROCK 2010
#  13                              Don't Dream It's Over  HARD ROCK 2010
#  14                                    Everywhere I Go  HARD ROCK 2010
#  15                                  Fall At Your Feet  HARD ROCK 2010
#  16                            Four Seasons In One Day  HARD ROCK 2010
#  17                                    Friend Like You  HARD ROCK 2010
#  18                         Get Lost Get High Get Sick  HARD ROCK 2010
#  19                                          Goodtimes  HARD ROCK 2010
#  20                                  Helplessly Hoping  HARD ROCK 2010
#  21                                        Here Before  HARD ROCK 2010
#  22                                         Here We Go  HARD ROCK 2010
#  23                                     I Am The Blaze  HARD ROCK 2010
#  24                                I Don't Believe You  HARD ROCK 2010
#  25                I'd Rather Be With You [Radio Edit]  HARD ROCK 2010
#  26                             If You Live Round Here  HARD ROCK 2010
#  27                                           In Sleep  HARD ROCK 2010
#  28                                        In The City  HARD ROCK 2010
#  29                         In You Are All The Stories  HARD ROCK 2010
#  30                               Keep Your Eyes On Me  HARD ROCK 2010
#  31                                          Lie To Me  HARD ROCK 2010
#  32                                      Little Lovin'  HARD ROCK 2010
#  33                                   Live And Let Die  HARD ROCK 2010
#  34                                 Man Who Used To Be  HARD ROCK 2010
#  35                                         Mastermind  HARD ROCK 2010
#  36                                    Nobody Wants To  HARD ROCK 2010
#  37                     Not The Girl You Think You Are  HARD ROCK 2010
#  38                                     Oh Mississippi  HARD ROCK 2010
#  39                                      Oliver's Army  HARD ROCK 2010
#  40         On All My Sundays - Liam Shachar Radio Mix  HARD ROCK 2010
#  41             On All My Sundays - Liam Shachar Remix  HARD ROCK 2010
#  42                                           Only You  HARD ROCK 2010
#  43                                     Out Of My Mind  HARD ROCK 2010
#  44                                  Personal Alcatraz  HARD ROCK 2010
#  45                            Phoenix In Dynamite Sky  HARD ROCK 2010
#  46                                           Pictures  HARD ROCK 2010
#  47                                Sailor's Sweetheart  HARD ROCK 2010
#  48                                     San Diego Song  HARD ROCK 2010  }

# %%
# Function to extract track names and artist names into a dictionary
def extract_tracks_metadata(data_files):
    tracks_metadata = {}
    for df_name, df in data_files.items():
        print(f"Processing DataFrame: {df_name}")
        # Strip leading and trailing spaces from column names
        df.columns = df.columns.str.strip()
        print(f"Columns in DataFrame: {df.columns}")
        if 'trackname' in df.columns and 'artistname' in df.columns:
            print("Both 'trackname' and 'artistname' columns found.")
            for index, row in df.iterrows():
                track_name = row['trackname']
                artist_name = row['artistname']
                print(f"Extracting track: {track_name}, Artist: {artist_name}")
                if track_name not in tracks_metadata:
                    tracks_metadata[track_name] = artist_name
                else:
                    print(f"Track '{track_name}' already exists in metadata.")
        else:
            print("Either 'trackname' or 'artistname' columns missing in DataFrame.")
    return tracks_metadata

    #{trackname: artistname}

# %%
def get_track_metadata_from_api(tracks_metadata, sp):
    extended_tracks_metadata = {}
    for index, (track_name, artist_name) in enumerate(tracks_metadata.items(), start=1):
        # Search for the track
        try:
            results = sp.search(q=f"track:{track_name} artist:{artist_name}", type='track', limit=1)
            if results['tracks']['items']:
                track_info = results['tracks']['items'][0]
                artist_uri = track_info["artists"][0]["uri"]
                artist_info = sp.artist(artist_uri)
                track_features = sp.audio_features(track_info['uri'])[0]

                # Extract release date
                release_date = track_info.get('album', {}).get('release_date', '')

                # Create a list with all the metadata
                metadata_list = [
                    artist_name,
                    track_features['acousticness'],
                    track_features['danceability'],
                    track_features['energy'],
                    track_features['instrumentalness'],
                    track_features['speechiness'],
                    track_features['liveness'],
                    track_features['loudness'],
                    track_features['tempo'],
                    track_features['valence'],
                    track_info['popularity'],
                    release_date,
                    artist_info["genres"]
                ]

                # Add the metadata list to the extended_tracks_metadata dictionary
                extended_tracks_metadata[track_name] = metadata_list

                print(f"{index}. Extended metadata for track '{track_name}': {metadata_list}")
            else:
                print(f"{index}. No results found for track '{track_name}'")
        except sp.SpotifyException as e:
            if e.http_status == 429:  # Too Many Requests
                print("Rate limit exceeded. Waiting before retrying...")
                time.sleep(10)  # Wait for 10 seconds before retrying
            else:
                print(f"Error while fetching track metadata: {e}")
    return extended_tracks_metadata


 #{trackname: [artistname, acousticness, danceability, energy, instrumentalness, speechiness, liveness, loudness, tempo, valence, popularity, genres]}

# %%
from google.colab import files

# Function to save tracks metadata as a CSV file
def save_tracks_metadata_to_csv(extended_tracks_metadata, output_file):
    # Create a DataFrame from tracks_metadata dictionary
    df = pd.DataFrame.from_dict(extended_tracks_metadata, orient='index')

    # Reset index and rename columns
    df.reset_index(inplace=True)
    df.columns = ['Track Name', 'Artist Name', 'Acousticness', 'Danceability', 'Energy', 'Instrumentalness',
                  'Speechiness', 'Liveness', 'Loudness', 'Tempo', 'Valence', 'Popularity', 'Release Date', 'Genres']

    # Save DataFrame to CSV file
    df.to_csv(output_file, index=False)

    # Download the CSV file
    files.download(output_file)

# %%
# Extract track metadata
tracks_metadata = extract_tracks_metadata(data_files)
# Out:
# Processing DataFrame: 50.csv
# Columns in DataFrame: Index(['user_id', 'artistname', 'trackname', 'playlistname'], dtype='object')
# Both 'trackname' and 'artistname' columns found.
# Extracting track: (The Angels Wanna Wear My) Red Shoes, Artist: Elvis Costello
# Extracting track: (What's So Funny 'Bout) Peace, Love And Understanding, Artist: Elvis Costello & The Attractions
# Extracting track: 7 Years Too Late, Artist: Tiffany Page
# Extracting track: Accidents Will Happen, Artist: Elvis Costello & The Attractions
# Extracting track: Alison, Artist: Elvis Costello
# Extracting track: All Be Okay, Artist: Lissie
# Extracting track: Band On The Run, Artist: Paul McCartney
# Extracting track: Beautiful, Artist: Joe Echo
# Extracting track: Blackbird - Live at CitiField, NYC - Digital Audio, Artist: Paul McCartney
# Extracting track: Bright Side, Artist: Lissie
# Extracting track: Dance The Go-Go, Artist: The Breakers
# Extracting track: Dance Tonight, Artist: Paul McCartney
# Extracting track: Decision Time, Artist: The Coronas
# Extracting track: Don't Dream It's Over, Artist: Crowded House
# Extracting track: Everywhere I Go, Artist: Lissie
# Extracting track: Fall At Your Feet, Artist: Crowded House
# Extracting track: Four Seasons In One Day, Artist: Crowded House
# Extracting track: Friend Like You, Artist: Joshua Radin
# Extracting track: Get Lost Get High Get Sick, Artist: The Breakers
# Extracting track: Goodtimes, Artist: Cocktail Slippers
# Extracting track: Helplessly Hoping, Artist: Crosby, Stills & Nash
# Extracting track: Here Before, Artist: Lissie
# Extracting track: Here We Go, Artist: Cocktail Slippers
# Extracting track: I Am The Blaze, Artist: Tiffany Page
# Extracting track: I Don't Believe You, Artist: The Len Price 3
# Extracting track: I'd Rather Be With You [Radio Edit], Artist: Joshua Radin
# Extracting track: If You Live Round Here, Artist: The Len Price 3
# Extracting track: In Sleep, Artist: Lissie
# Extracting track: In The City, Artist: Cocktail Slippers
# Extracting track: In You Are All The Stories, Artist: Joe Echo
# Extracting track: Keep Your Eyes On Me, Artist: The Len Price 3
# Extracting track: Lie To Me, Artist: Joe Echo
# Extracting track: Little Lovin', Artist: Lissie
# Extracting track: Live And Let Die, Artist: Paul McCartney
# Extracting track: Man Who Used To Be, Artist: The Len Price 3
# Extracting track: Mastermind, Artist: Cocktail Slippers
# Extracting track: Nobody Wants To, Artist: Crowded House
# Extracting track: Not The Girl You Think You Are, Artist: Crowded House
# Extracting track: Oh Mississippi, Artist: Lissie
# Extracting track: Oliver's Army, Artist: Elvis Costello & The Attractions
# Extracting track: On All My Sundays - Liam Shachar Radio Mix, Artist: Joe Echo
# Extracting track: On All My Sundays - Liam Shachar Remix, Artist: Joe Echo
# Extracting track: Only You, Artist: Joshua Radin
# Extracting track: Out Of My Mind, Artist: Tiffany Page
# Extracting track: Personal Alcatraz, Artist: Joe Echo
# Extracting track: Phoenix In Dynamite Sky, Artist: Joe Echo
# Extracting track: Pictures, Artist: The Len Price 3
# Extracting track: Sailor's Sweetheart, Artist: The Len Price 3
# Extracting track: San Diego Song, Artist: The Coronas

# %%
tracks_metadata
# Out:
# {'(The Angels Wanna Wear My) Red Shoes': 'Elvis Costello',
#  "(What's So Funny 'Bout) Peace, Love And Understanding": 'Elvis Costello & The Attractions',
#  '7 Years Too Late': 'Tiffany Page',
#  'Accidents Will Happen': 'Elvis Costello & The Attractions',
#  'Alison': 'Elvis Costello',
#  'All Be Okay': 'Lissie',
#  'Band On The Run': 'Paul McCartney',
#  'Beautiful': 'Joe Echo',
#  'Blackbird - Live at CitiField, NYC - Digital Audio': 'Paul McCartney',
#  'Bright Side': 'Lissie',
#  'Dance The Go-Go': 'The Breakers',
#  'Dance Tonight': 'Paul McCartney',
#  'Decision Time': 'The Coronas',
#  "Don't Dream It's Over": 'Crowded House',
#  'Everywhere I Go': 'Lissie',
#  'Fall At Your Feet': 'Crowded House',
#  'Four Seasons In One Day': 'Crowded House',
#  'Friend Like You': 'Joshua Radin',
#  'Get Lost Get High Get Sick': 'The Breakers',
#  'Goodtimes': 'Cocktail Slippers',
#  'Helplessly Hoping': 'Crosby, Stills & Nash',
#  'Here Before': 'Lissie',
#  'Here We Go': 'Cocktail Slippers',
#  'I Am The Blaze': 'Tiffany Page',
#  "I Don't Believe You": 'The Len Price 3',
#  "I'd Rather Be With You [Radio Edit]": 'Joshua Radin',
#  'If You Live Round Here': 'The Len Price 3',
#  'In Sleep': 'Lissie',
#  'In The City': 'Cocktail Slippers',
#  'In You Are All The Stories': 'Joe Echo',
#  'Keep Your Eyes On Me': 'The Len Price 3',
#  'Lie To Me': 'Joe Echo',
#  "Little Lovin'": 'Lissie',
#  'Live And Let Die': 'Paul McCartney',
#  'Man Who Used To Be': 'The Len Price 3',
#  'Mastermind': 'Cocktail Slippers',
#  'Nobody Wants To': 'Crowded House',
#  'Not The Girl You Think You Are': 'Crowded House',
#  'Oh Mississippi': 'Lissie',
#  "Oliver's Army": 'Elvis Costello & The Attractions',
#  'On All My Sundays - Liam Shachar Radio Mix': 'Joe Echo',
#  'On All My Sundays - Liam Shachar Remix': 'Joe Echo',
#  'Only You': 'Joshua Radin',
#  'Out Of My Mind': 'Tiffany Page',
#  'Personal Alcatraz': 'Joe Echo',
#  'Phoenix In Dynamite Sky': 'Joe Echo',
#  'Pictures': 'The Len Price 3',
#  "Sailor's Sweetheart": 'The Len Price 3',
#  'San Diego Song': 'The Coronas'}

# %%
# Read Spotify credentials from URL
spotify_credentials_url = 'https://raw.githubusercontent.com/ariel-hedvat/AdvancedMLDLCourseAssignments/main/Experiments/Data/eitans_spotify_credentials.txt'
spotify_credentials = read_spotify_credentials_from_url(spotify_credentials_url)

# Initialize Spotipy client with the obtained credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=spotify_credentials['CLIENT_ID'],
                                                           client_secret=spotify_credentials['CLIENT_SECRET']))

# %%
# Assuming tracks_metadata is already populated with track names and artist names
# Call the function to retrieve metadata for each track
extended_tracks_metadata = get_track_metadata_from_api(tracks_metadata, sp)
# Out:
# 1. Extended metadata for track '(The Angels Wanna Wear My) Red Shoes': ['Elvis Costello', 0.0556, 0.577, 0.636, 0.00016, 0.0491, 0.226, -9.825, 134.768, 0.901, 41, '1977-07-22', ['new wave', 'new wave pop', 'permanent wave', 'power pop', 'singer-songwriter']]
# 2. Extended metadata for track '(What's So Funny 'Bout) Peace, Love And Understanding': ['Elvis Costello & The Attractions', 0.000466, 0.381, 0.918, 0.0511, 0.0803, 0.321, -9.451, 142.34, 0.368, 44, '2020-11-06', ['art rock', 'heartland rock', 'new romantic', 'new wave', 'new wave pop', 'power pop']]
# 3. No results found for track '7 Years Too Late'
# 4. Extended metadata for track 'Accidents Will Happen': ['Elvis Costello & The Attractions', 0.0441, 0.608, 0.597, 0.00342, 0.0276, 0.285, -11.115, 120.077, 0.736, 38, '2020-11-06', ['art rock', 'heartland rock', 'new romantic', 'new wave', 'new wave pop', 'power pop']]
# 5. Extended metadata for track 'Alison': ['Elvis Costello', 0.739, 0.557, 0.32, 3.99e-05, 0.0438, 0.112, -10.792, 176.647, 0.377, 55, '1977-07-22', ['new wave', 'new wave pop', 'permanent wave', 'power pop', 'singer-songwriter']]
# 6. Extended metadata for track 'All Be Okay': ['Lissie', 0.028, 0.582, 0.643, 0, 0.0309, 0.0974, -6.047, 122.084, 0.533, 14, '2021-09-10', ['folk-pop']]
# 7. Extended metadata for track 'Band On The Run': ['Paul McCartney', 0.0832, 0.479, 0.601, 0.00142, 0.0318, 0.11, -8.806, 124.966, 0.669, 73, '1973-12-05', ['classic rock', 'mellow gold', 'rock', 'soft rock']]
# 8. Extended metadata for track 'Beautiful': ['Joe Echo', 0.888, 0.428, 0.279, 1.66e-05, 0.0291, 0.0809, -12.862, 139.057, 0.2, 2, '2010-01-01', []]
# 9. No results found for track 'Blackbird - Live at CitiField, NYC - Digital Audio'
# 10. No results found for track 'Bright Side'
# 11. Extended metadata for track 'Dance The Go-Go': ['The Breakers', 0.0301, 0.471, 0.91, 0, 0.0648, 0.347, -2.472, 112.293, 0.684, 6, '2006-01-23', ['danish alternative rock']]
# 12. Extended metadata for track 'Dance Tonight': ['Paul McCartney', 0.0823, 0.531, 0.891, 0.00551, 0.0431, 0.161, -2.539, 170.973, 0.926, 38, '2007-06-04', ['classic rock', 'mellow gold', 'rock', 'soft rock']]
# 13. Extended metadata for track 'Decision Time': ['The Coronas', 0.0153, 0.508, 0.471, 1.79e-05, 0.0303, 0.113, -8.645, 141.063, 0.447, 11, '2007-10-05', ['irish rock']]
# 14. Extended metadata for track 'Don't Dream It's Over': ['Crowded House', 0.71, 0.502, 0.683, 1.98e-06, 0.0472, 0.18, -8.19, 82.626, 0.734, 19, '2016-01-01', ['australian rock', 'permanent wave']]
# 15. Extended metadata for track 'Everywhere I Go': ['Lissie', 0.87, 0.448, 0.184, 0, 0.0338, 0.0946, -10.443, 93.425, 0.151, 42, '2010-06-21', ['folk-pop']]
# 16. Extended metadata for track 'Fall At Your Feet': ['Crowded House', 0.457, 0.65, 0.371, 0.0116, 0.026, 0.102, -13.623, 102.583, 0.561, 62, '1991-06-24', ['australian rock', 'permanent wave']]
# 17. Extended metadata for track 'Four Seasons In One Day': ['Crowded House', 0.816, 0.517, 0.261, 0.000163, 0.0263, 0.0863, -17.196, 89.221, 0.492, 56, '1991-06-24', ['australian rock', 'permanent wave']]
# 18. Extended metadata for track 'Friend Like You': ['Joshua Radin', 0.54, 0.571, 0.262, 0.0408, 0.0357, 0.141, -17.502, 87.891, 0.19, 17, '2008-09-30', ['acoustic pop', 'neo mellow']]
# 19. Extended metadata for track 'Get Lost Get High Get Sick': ['The Breakers', 0.00171, 0.461, 0.87, 2.95e-05, 0.0302, 0.299, -3.022, 97.375, 0.832, 1, '2006-01-23', ['danish alternative rock']]
# 20. Extended metadata for track 'Goodtimes': ['Cocktail Slippers', 0.0016, 0.396, 0.962, 0, 0.0512, 0.106, -3.672, 143.153, 0.574, 1, '2002-01-31', ['garage rock revival']]
# 21. Extended metadata for track 'Helplessly Hoping': ['Crosby, Stills & Nash', 0.914, 0.483, 0.159, 0, 0.0353, 0.111, -13.648, 146.721, 0.423, 69, '1969-05-29', ['album rock', 'classic rock', 'country rock', 'folk', 'folk rock', 'heartland rock', 'mellow gold', 'rock', 'soft rock']]
# 22. Extended metadata for track 'Here Before': ['Lissie', 0.376, 0.407, 0.316, 7.33e-05, 0.0305, 0.0882, -9.728, 88.4, 0.0703, 16, '2009', ['folk-pop']]
# 23. Extended metadata for track 'Here We Go': ['Cocktail Slippers', 0.000207, 0.333, 0.941, 3.18e-06, 0.0481, 0.386, -3.238, 115.281, 0.571, 2, '2002-01-31', ['garage rock revival']]
# 24. Extended metadata for track 'I Am The Blaze': ['Tiffany Page', 0.148, 0.172, 0.669, 0.00156, 0.0396, 0.0738, -6.005, 146.912, 0.0763, 1, '2020-07-17', []]
# 25. Extended metadata for track 'I Don't Believe You': ['The Len Price 3', 0.00494, 0.368, 0.952, 0.000413, 0.0405, 0.194, -4.168, 157.648, 0.952, 1, '2010-01-31', ['garage rock revival', 'medway sound', 'mod revival', 'underground power pop']]
# 26. No results found for track 'I'd Rather Be With You [Radio Edit]'
# 27. Extended metadata for track 'If You Live Round Here': ['The Len Price 3', 0.0609, 0.439, 0.81, 0, 0.0363, 0.0944, -3.82, 146.227, 0.893, 1, '2010-01-31', ['garage rock revival', 'medway sound', 'mod revival', 'underground power pop']]
# 28. Extended metadata for track 'In Sleep': ['Lissie', 0.000922, 0.625, 0.834, 2.76e-06, 0.0356, 0.189, -5.727, 133.017, 0.709, 38, '2010-06-21', ['folk-pop']]
# 29. Extended metadata for track 'In The City': ['Cocktail Slippers', 0.00313, 0.405, 0.91, 3.72e-06, 0.045, 0.535, -3.474, 145.722, 0.708, 5, '2009-01-31', ['garage rock revival']]
# 30. Extended metadata for track 'In You Are All The Stories': ['Joe Echo', 0.283, 0.515, 0.9, 0, 0.0713, 0.336, -4.846, 75.008, 0.837, 1, '2010-01-01', []]
# 31. Extended metadata for track 'Keep Your Eyes On Me': ['The Len Price 3', 3.58e-05, 0.362, 0.905, 0.000101, 0.0315, 0.304, -3.58, 145.088, 0.937, 3, '2010-01-31', ['garage rock revival', 'medway sound', 'mod revival', 'underground power pop']]
# 32. Extended metadata for track 'Lie To Me': ['Joe Echo', 0.324, 0.678, 0.784, 0, 0.0317, 0.143, -6.145, 103.982, 0.79, 1, '2010-01-01', []]
# 33. Extended metadata for track 'Little Lovin'': ['Lissie', 0.557, 0.599, 0.712, 0.00102, 0.0487, 0.122, -6.556, 116.047, 0.378, 39, '2010-06-21', ['folk-pop']]
# 34. Extended metadata for track 'Live And Let Die': ['Paul McCartney', 0.784, 0.236, 0.38, 0.559, 0.0551, 0.114, -18.93, 74.338, 0.111, 4, '2024-03-10', ['classic rock', 'mellow gold', 'rock', 'soft rock']]
# 35. Extended metadata for track 'Man Who Used To Be': ['The Len Price 3', 6.44e-05, 0.264, 0.912, 3.49e-05, 0.0805, 0.355, -3.67, 169.183, 0.707, 2, '2010-01-31', ['garage rock revival', 'medway sound', 'mod revival', 'underground power pop']]
# 36. Extended metadata for track 'Mastermind': ['Cocktail Slippers', 5.17e-05, 0.346, 0.816, 0.00277, 0.046, 0.119, -4.684, 147.541, 0.455, 2, '2007-01-31', ['garage rock revival']]
# 37. Extended metadata for track 'Nobody Wants To': ['Crowded House', 0.638, 0.371, 0.552, 0.00461, 0.0253, 0.107, -7.678, 173.259, 0.477, 25, '2007-06-25', ['australian rock', 'permanent wave']]
# 38. Extended metadata for track 'Not The Girl You Think You Are': ['Crowded House', 0.816, 0.547, 0.365, 1.22e-05, 0.0244, 0.106, -11.34, 93.802, 0.292, 36, '2010-10-15', ['australian rock', 'permanent wave']]
# 39. Extended metadata for track 'Oh Mississippi': ['Lissie', 0.881, 0.359, 0.274, 0.00139, 0.0262, 0.115, -8.319, 100.13, 0.23, 26, '2010-06-21', ['folk-pop']]
# 40. No results found for track 'Oliver's Army'
# 41. Extended metadata for track 'On All My Sundays - Liam Shachar Radio Mix': ['Joe Echo', 0.00179, 0.563, 0.839, 0.336, 0.0344, 0.0722, -6.626, 125.983, 0.403, 1, '2008-02-19', []]
# 42. Extended metadata for track 'On All My Sundays - Liam Shachar Remix': ['Joe Echo', 0.000634, 0.631, 0.891, 0.726, 0.0355, 0.0903, -7.322, 125.985, 0.385, 1, '2008-02-19', []]
# 43. Extended metadata for track 'Only You': ['Joshua Radin', 0.362, 0.545, 0.255, 1.77e-05, 0.0311, 0.0841, -14.844, 98.088, 0.831, 51, '2006', ['acoustic pop', 'neo mellow']]
# 44. Extended metadata for track 'Out Of My Mind': ['Tiffany Page', 0.00108, 0.632, 0.913, 1.93e-06, 0.0337, 0.144, -4.75, 123.022, 0.843, 0, '2020-07-17', []]
# 45. Extended metadata for track 'Personal Alcatraz': ['Joe Echo', 0.164, 0.74, 0.721, 0, 0.0275, 0.0704, -5.885, 114.489, 0.504, 0, '2007-06-17', []]
# 46. Extended metadata for track 'Phoenix In Dynamite Sky': ['Joe Echo', 0.00227, 0.616, 0.689, 0.34, 0.0361, 0.0897, -10.076, 119.999, 0.116, 1, '2010-01-01', []]
# 47. Extended metadata for track 'Pictures': ['The Len Price 3', 0.00486, 0.367, 0.893, 0, 0.0587, 0.0935, -3.03, 157.599, 0.706, 2, '2010-01-31', ['garage rock revival', 'medway sound', 'mod revival', 'underground power pop']]
# 48. Extended metadata for track 'Sailor's Sweetheart': ['The Len Price 3', 0.216, 0.415, 0.955, 0.00334, 0.0633, 0.39, -1.481, 126.563, 0.767, 3, '2007-01-31', ['garage rock revival', 'medway sound', 'mod revival', 'underground power pop']]
# 49. Extended metadata for track 'San Diego Song': ['The Coronas', 0.00421, 0.409, 0.655, 0, 0.0356, 0.183, -5.965, 170.852, 0.353, 40, '2007-10-05', ['irish rock']]

# %%
extended_tracks_metadata
# Out:
# {'(The Angels Wanna Wear My) Red Shoes': ['Elvis Costello',
#   0.0556,
#   0.577,
#   0.636,
#   0.00016,
#   0.0491,
#   0.226,
#   -9.825,
#   134.768,
#   0.901,
#   41,
#   '1977-07-22',
#   ['new wave',
#    'new wave pop',
#    'permanent wave',
#    'power pop',
#    'singer-songwriter']],
#  "(What's So Funny 'Bout) Peace, Love And Understanding": ['Elvis Costello & The Attractions',
#   0.000466,
#   0.381,
#   0.918,
#   0.0511,
#   0.0803,
#   0.321,
#   -9.451,
#   142.34,
#   0.368,
#   44,
#   '2020-11-06',
#   ['art rock',
#    'heartland rock',
#    'new romantic',
#    'new wave',
#    'new wave pop',
#    'power pop']],
#  'Accidents Will Happen': ['Elvis Costello & The Attractions',
#   0.0441,
#   0.608,
#   0.597,
#   0.00342,
#   0.0276,
#   0.285,
#   -11.115,
#   120.077,
#   0.736,
#   38,
#   '2020-11-06',
#   ['art rock',
#    'heartland rock',
#    'new romantic',
#    'new wave',
#    'new wave pop',
#    'power pop']],
#  'Alison': ['Elvis Costello',
#   0.739,
#   0.557,
#   0.32,
#   3.99e-05,
#   0.0438,
#   0.112,
#   -10.792,
#   176.647,
#   0.377,
#   55,
#   '1977-07-22',
#   ['new wave',
#    'new wave pop',
#    'permanent wave',
#    'power pop',
#    'singer-songwriter']],
#  'All Be Okay': ['Lissie',
#   0.028,
#   0.582,
#   0.643,
#   0,
#   0.0309,
#   0.0974,
#   -6.047,
#   122.084,
#   0.533,
#   14,
#   '2021-09-10',
#   ['folk-pop']],
#  'Band On The Run': ['Paul McCartney',
#   0.0832,
#   0.479,
#   0.601,
#   0.00142,
#   0.0318,
#   0.11,
#   -8.806,
#   124.966,
#   0.669,
#   73,
#   '1973-12-05',
#   ['classic rock', 'mellow gold', 'rock', 'soft rock']],
#  'Beautiful': ['Joe Echo',
#   0.888,
#   0.428,
#   0.279,
#   1.66e-05,
#   0.0291,
#   0.0809,
#   -12.862,
#   139.057,
#   0.2,
#   2,
#   '2010-01-01',
#   []],
#  'Dance The Go-Go': ['The Breakers',
#   0.0301,
#   0.471,
#   0.91,
#   0,
#   0.0648,
#   0.347,
#   -2.472,
#   112.293,
#   0.684,
#   6,
#   '2006-01-23',
#   ['danish alternative rock']],
#  'Dance Tonight': ['Paul McCartney',
#   0.0823,
#   0.531,
#   0.891,
#   0.00551,
#   0.0431,
#   0.161,
#   -2.539,
#   170.973,
#   0.926,
#   38,
#   '2007-06-04',
#   ['classic rock', 'mellow gold', 'rock', 'soft rock']],
#  'Decision Time': ['The Coronas',
#   0.0153,
#   0.508,
#   0.471,
#   1.79e-05,
#   0.0303,
#   0.113,
#   -8.645,
#   141.063,
#   0.447,
#   11,
#   '2007-10-05',
#   ['irish rock']],
#  "Don't Dream It's Over": ['Crowded House',
#   0.71,
#   0.502,
#   0.683,
#   1.98e-06,
#   0.0472,
#   0.18,
#   -8.19,
#   82.626,
#   0.734,
#   19,
#   '2016-01-01',
#   ['australian rock', 'permanent wave']],
#  'Everywhere I Go': ['Lissie',
#   0.87,
#   0.448,
#   0.184,
#   0,
#   0.0338,
#   0.0946,
#   -10.443,
#   93.425,
#   0.151,
#   42,
#   '2010-06-21',
#   ['folk-pop']],
#  'Fall At Your Feet': ['Crowded House',
#   0.457,
#   0.65,
#   0.371,
#   0.0116,
#   0.026,
#   0.102,
#   -13.623,
#   102.583,
#   0.561,
#   62,
#   '1991-06-24',
#   ['australian rock', 'permanent wave']],
#  'Four Seasons In One Day': ['Crowded House',
#   0.816,
#   0.517,
#   0.261,
#   0.000163,
#   0.0263,
#   0.0863,
#   -17.196,
#   89.221,
#   0.492,
#   56,
#   '1991-06-24',
#   ['australian rock', 'permanent wave']],
#  'Friend Like You': ['Joshua Radin',
#   0.54,
#   0.571,
#   0.262,
#   0.0408,
#   0.0357,
#   0.141,
#   -17.502,
#   87.891,
#   0.19,
#   17,
#   '2008-09-30',
#   ['acoustic pop', 'neo mellow']],
#  'Get Lost Get High Get Sick': ['The Breakers',
#   0.00171,
#   0.461,
#   0.87,
#   2.95e-05,
#   0.0302,
#   0.299,
#   -3.022,
#   97.375,
#   0.832,
#   1,
#   '2006-01-23',
#   ['danish alternative rock']],
#  'Goodtimes': ['Cocktail Slippers',
#   0.0016,
#   0.396,
#   0.962,
#   0,
#   0.0512,
#   0.106,
#   -3.672,
#   143.153,
#   0.574,
#   1,
#   '2002-01-31',
#   ['garage rock revival']],
#  'Helplessly Hoping': ['Crosby, Stills & Nash',
#   0.914,
#   0.483,
#   0.159,
#   0,
#   0.0353,
#   0.111,
#   -13.648,
#   146.721,
#   0.423,
#   69,
#   '1969-05-29',
#   ['album rock',
#    'classic rock',
#    'country rock',
#    'folk',
#    'folk rock',
#    'heartland rock',
#    'mellow gold',
#    'rock',
#    'soft rock']],
#  'Here Before': ['Lissie',
#   0.376,
#   0.407,
#   0.316,
#   7.33e-05,
#   0.0305,
#   0.0882,
#   -9.728,
#   88.4,
#   0.0703,
#   16,
#   '2009',
#   ['folk-pop']],
#  'Here We Go': ['Cocktail Slippers',
#   0.000207,
#   0.333,
#   0.941,
#   3.18e-06,
#   0.0481,
#   0.386,
#   -3.238,
#   115.281,
#   0.571,
#   2,
#   '2002-01-31',
#   ['garage rock revival']],
#  'I Am The Blaze': ['Tiffany Page',
#   0.148,
#   0.172,
#   0.669,
#   0.00156,
#   0.0396,
#   0.0738,
#   -6.005,
#   146.912,
#   0.0763,
#   1,
#   '2020-07-17',
#   []],
#  "I Don't Believe You": ['The Len Price 3',
#   0.00494,
#   0.368,
#   0.952,
#   0.000413,
#   0.0405,
#   0.194,
#   -4.168,
#   157.648,
#   0.952,
#   1,
#   '2010-01-31',
#   ['garage rock revival',
#    'medway sound',
#    'mod revival',
#    'underground power pop']],
#  'If You Live Round Here': ['The Len Price 3',
#   0.0609,
#   0.439,
#   0.81,
#   0,
#   0.0363,
#   0.0944,
#   -3.82,
#   146.227,
#   0.893,
#   1,
#   '2010-01-31',
#   ['garage rock revival',
#    'medway sound',
#    'mod revival',
#    'underground power pop']],
#  'In Sleep': ['Lissie',
#   0.000922,
#   0.625,
#   0.834,
#   2.76e-06,
#   0.0356,
#   0.189,
#   -5.727,
#   133.017,
#   0.709,
#   38,
#   '2010-06-21',
#   ['folk-pop']],
#  'In The City': ['Cocktail Slippers',
#   0.00313,
#   0.405,
#   0.91,
#   3.72e-06,
#   0.045,
#   0.535,
#   -3.474,
#   145.722,
#   0.708,
#   5,
#   '2009-01-31',
#   ['garage rock revival']],
#  'In You Are All The Stories': ['Joe Echo',
#   0.283,
#   0.515,
#   0.9,
#   0,
#   0.0713,
#   0.336,
#   -4.846,
#   75.008,
#   0.837,
#   1,
#   '2010-01-01',
#   []],
#  'Keep Your Eyes On Me': ['The Len Price 3',
#   3.58e-05,
#   0.362,
#   0.905,
#   0.000101,
#   0.0315,
#   0.304,
#   -3.58,
#   145.088,
#   0.937,
#   3,
#   '2010-01-31',
#   ['garage rock revival',
#    'medway sound',
#    'mod revival',
#    'underground power pop']],
#  'Lie To Me': ['Joe Echo',
#   0.324,
#   0.678,
#   0.784,
#   0,
#   0.0317,
#   0.143,
#   -6.145,
#   103.982,
#   0.79,
#   1,
#   '2010-01-01',
#   []],
#  "Little Lovin'": ['Lissie',
#   0.557,
#   0.599,
#   0.712,
#   0.00102,
#   0.0487,
#   0.122,
#   -6.556,
#   116.047,
#   0.378,
#   39,
#   '2010-06-21',
#   ['folk-pop']],
#  'Live And Let Die': ['Paul McCartney',
#   0.784,
#   0.236,
#   0.38,
#   0.559,
#   0.0551,
#   0.114,
#   -18.93,
#   74.338,
#   0.111,
#   4,
#   '2024-03-10',
#   ['classic rock', 'mellow gold', 'rock', 'soft rock']],
#  'Man Who Used To Be': ['The Len Price 3',
#   6.44e-05,
#   0.264,
#   0.912,
#   3.49e-05,
#   0.0805,
#   0.355,
#   -3.67,
#   169.183,
#   0.707,
#   2,
#   '2010-01-31',
#   ['garage rock revival',
#    'medway sound',
#    'mod revival',
#    'underground power pop']],
#  'Mastermind': ['Cocktail Slippers',
#   5.17e-05,
#   0.346,
#   0.816,
#   0.00277,
#   0.046,
#   0.119,
#   -4.684,
#   147.541,
#   0.455,
#   2,
#   '2007-01-31',
#   ['garage rock revival']],
#  'Nobody Wants To': ['Crowded House',
#   0.638,
#   0.371,
#   0.552,
#   0.00461,
#   0.0253,
#   0.107,
#   -7.678,
#   173.259,
#   0.477,
#   25,
#   '2007-06-25',
#   ['australian rock', 'permanent wave']],
#  'Not The Girl You Think You Are': ['Crowded House',
#   0.816,
#   0.547,
#   0.365,
#   1.22e-05,
#   0.0244,
#   0.106,
#   -11.34,
#   93.802,
#   0.292,
#   36,
#   '2010-10-15',
#   ['australian rock', 'permanent wave']],
#  'Oh Mississippi': ['Lissie',
#   0.881,
#   0.359,
#   0.274,
#   0.00139,
#   0.0262,
#   0.115,
#   -8.319,
#   100.13,
#   0.23,
#   26,
#   '2010-06-21',
#   ['folk-pop']],
#  'On All My Sundays - Liam Shachar Radio Mix': ['Joe Echo',
#   0.00179,
#   0.563,
#   0.839,
#   0.336,
#   0.0344,
#   0.0722,
#   -6.626,
#   125.983,
#   0.403,
#   1,
#   '2008-02-19',
#   []],
#  'On All My Sundays - Liam Shachar Remix': ['Joe Echo',
#   0.000634,
#   0.631,
#   0.891,
#   0.726,
#   0.0355,
#   0.0903,
#   -7.322,
#   125.985,
#   0.385,
#   1,
#   '2008-02-19',
#   []],
#  'Only You': ['Joshua Radin',
#   0.362,
#   0.545,
#   0.255,
#   1.77e-05,
#   0.0311,
#   0.0841,
#   -14.844,
#   98.088,
#   0.831,
#   51,
#   '2006',
#   ['acoustic pop', 'neo mellow']],
#  'Out Of My Mind': ['Tiffany Page',
#   0.00108,
#   0.632,
#   0.913,
#   1.93e-06,
#   0.0337,
#   0.144,
#   -4.75,
#   123.022,
#   0.843,
#   0,
#   '2020-07-17',
#   []],
#  'Personal Alcatraz': ['Joe Echo',
#   0.164,
#   0.74,
#   0.721,
#   0,
#   0.0275,
#   0.0704,
#   -5.885,
#   114.489,
#   0.504,
#   0,
#   '2007-06-17',
#   []],
#  'Phoenix In Dynamite Sky': ['Joe Echo',
#   0.00227,
#   0.616,
#   0.689,
#   0.34,
#   0.0361,
#   0.0897,
#   -10.076,
#   119.999,
#   0.116,
#   1,
#   '2010-01-01',
#   []],
#  'Pictures': ['The Len Price 3',
#   0.00486,
#   0.367,
#   0.893,
#   0,
#   0.0587,
#   0.0935,
#   -3.03,
#   157.599,
#   0.706,
#   2,
#   '2010-01-31',
#   ['garage rock revival',
#    'medway sound',
#    'mod revival',
#    'underground power pop']],
#  "Sailor's Sweetheart": ['The Len Price 3',
#   0.216,
#   0.415,
#   0.955,
#   0.00334,
#   0.0633,
#   0.39,
#   -1.481,
#   126.563,
#   0.767,
#   3,
#   '2007-01-31',
#   ['garage rock revival',
#    'medway sound',
#    'mod revival',
#    'underground power pop']],
#  'San Diego Song': ['The Coronas',
#   0.00421,
#   0.409,
#   0.655,
#   0,
#   0.0356,
#   0.183,
#   -5.965,
#   170.852,
#   0.353,
#   40,
#   '2007-10-05',
#   ['irish rock']]}

# %%
# Save tracks metadata to CSV
output_file = 'extended_tracks_metadata.csv'
save_tracks_metadata_to_csv(extended_tracks_metadata, output_file)
